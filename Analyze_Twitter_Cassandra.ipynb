# %% [markdown]
# ## Reading and creating new table in Cassandra

# %%
import json
from cassandra import ConsistencyLevel
from cassandra.cluster import Cluster, BatchStatement
from cassandra.query import SimpleStatement
from cassandra.auth import PlainTextAuthProvider
from cassandra import InvalidRequest as CE
import pandas as pd

## Cassandra credentials
cassandrauser = 'cassandra'
casspassword = 'cassandra'
host_list = 'localhost'
cassandra_port =9042

### Create connection to cassandra database.

def connect_cassandra():
    auth_provider = PlainTextAuthProvider(username=cassandrauser,password=casspassword)
    cluster = Cluster([host_list],protocol_version=4,
                      auth_provider = auth_provider,port=cassandra_port)
    session = cluster.connect()
    session.set_keyspace('twitter')
    return  session

cursor_twitter = connect_cassandra()

# %% [markdown]
# ### Reading data from tweets_coronavirus to a dataframe.

# %%
query = "select * from tweets_coronavirus"
tweets_coronavirus = pd.DataFrame(list(cursor_twitter.execute(query)))
tweets_coronavirus.head(10)
# Out:
#                                      id                      created_at  \
# 0  23440890-75d0-11ea-933c-d984957af244  Fri Apr 03 17:25:34 +0000 2020
# 1  233c23e0-75d1-11ea-933c-d984957af244  Fri Apr 03 17:32:43 +0000 2020
# 2  75ef0ef0-75d0-11ea-933c-d984957af244  Fri Apr 03 17:27:52 +0000 2020
# 3  e4a60620-75ce-11ea-933c-d984957af244  Fri Apr 03 17:16:39 +0000 2020
# 4  4edf3d60-75cd-11ea-933c-d984957af244  Fri Apr 03 17:05:18 +0000 2020
# 5  de4c0c20-75ce-11ea-933c-d984957af244  Fri Apr 03 17:16:29 +0000 2020
# 6  42e34ec0-75cd-11ea-933c-d984957af244  Fri Apr 03 17:04:58 +0000 2020
# 7  660d6200-75cd-11ea-933c-d984957af244  Fri Apr 03 17:05:57 +0000 2020
# 8  942e2180-75d0-11ea-933c-d984957af244  Fri Apr 03 17:28:43 +0000 2020
# 9  e2337820-75d1-11ea-933c-d984957af244  Fri Apr 03 17:38:04 +0000 2020
#
#                                          fullmessage  \
# 0  {"created_at":"Fri Apr 03 17:25:34 +0000 2020"...
# 1  {"created_at":"Fri Apr 03 17:32:43 +0000 2020"...
# 2  {"created_at":"Fri Apr 03 17:27:52 +0000 2020"...
# 3  {"created_at":"Fri Apr 03 17:16:39 +0000 2020"...
# 4  {"created_at":"Fri Apr 03 17:05:18 +0000 2020"...
# 5  {"created_at":"Fri Apr 03 17:16:29 +0000 2020"...
# 6  {"created_at":"Fri Apr 03 17:04:58 +0000 2020"...
# 7  {"created_at":"Fri Apr 03 17:05:57 +0000 2020"...
# 8  {"created_at":"Fri Apr 03 17:28:43 +0000 2020"...
# 9  {"created_at":"Fri Apr 03 17:38:04 +0000 2020"...
#
#                        location           place  retweetcount  \
# 0                          None            None             0
# 1                            🇳🇬            None             0
# 2              Connecticut, USA            None             0
# 3       Port Mouton, NS  Canada            None             0
# 4  Albuquerque, New Mexico, USA            None             0
# 5             Falmouth, England  United Kingdom             0
# 6     D.M.V. (Eastern shore Md)            None             0
# 7                    Gród Lecha            None             0
# 8                          None            None             0
# 9                 Brooklyn, NY             None             0
#
#                                                tweet             user_id
# 0  RT @o_rips: US population 327,200,000\n\n7,452...  783040259437101057
# 1  RT @todayng: Coronavirus: Didier Drogba slams ...           237738614
# 2  A national outbreak calls for a national respo...           278124059
# 3  RT @MaximeBernier: The problem with the Trudea...           951666961
# 4  RT @RepBarbaraLee: Even Trump’s own experts ag...            24886197
# 5  A tide is turning. Making Health and Nutrition...            24881428
# 6  RT @bsonenstein: here's a better idea than giv...           165452390
# 7  RT @SpeedBird_NCL: The big picture: KLM fleet ...           369581565
# 8  RT @PENamerica: Professors send open letter to...           837698190
# 9                                            Damn 😔🥺            62115298

# %% [markdown]
# ### Filter the users that have posted more than 20 tweets

# %%
tweets_count = pd.DataFrame(tweets_coronavirus.groupby('user_id').filter(lambda x: (x['tweet']).count() > 20 ))
tweets_count.head(5)
# Out:
#                                         id                      created_at  \
# 185   280ff310-75d1-11ea-933c-d984957af244  Fri Apr 03 17:32:51 +0000 2020
# 231   6c449c50-75ce-11ea-933c-d984957af244  Fri Apr 03 17:13:17 +0000 2020
# 390   b8454950-75cf-11ea-933c-d984957af244  Fri Apr 03 17:22:34 +0000 2020
# 967   516db3a0-75d1-11ea-933c-d984957af244  Fri Apr 03 17:34:01 +0000 2020
# 1136  7369a720-75d1-11ea-933c-d984957af244  Fri Apr 03 17:34:58 +0000 2020
#
#                                             fullmessage  \
# 185   {"created_at":"Fri Apr 03 17:32:51 +0000 2020"...
# 231   {"created_at":"Fri Apr 03 17:13:17 +0000 2020"...
# 390   {"created_at":"Fri Apr 03 17:22:34 +0000 2020"...
# 967   {"created_at":"Fri Apr 03 17:34:01 +0000 2020"...
# 1136  {"created_at":"Fri Apr 03 17:34:58 +0000 2020"...
#
#                           location place  retweetcount  \
# 185   New Haven,  Connecticut, USA  None             0
# 231                           None  None             0
# 390                           None  None             0
# 967                           None  None             0
# 1136                            LA  None             0
#
#                                                   tweet              user_id
# 185   RT @peterbakernyt: The CIA has been warning th...             72677520
# 231   RT @NehaBindal10: #SelflessServiceByDSSVolunte...  1236616242544295936
# 390   RT @RepStefanik: Thanks to @RepGallagher, @Rep...  1175794398476427264
# 967   RT @BuzzFeedNews: The White House announced a ...  1238467680773894146
# 1136  RT @PressSec: Many American companies have ans...             49380102

# %%
query = "create table if not exists tweets_count(user_id text, location text, tweet text, retweet_count int,created_at text,PRIMARY KEY(user_id, created_at))"
prepared = cursor_twitter.execute(query)

# %%
tweets_count.columns
# Out:
# Index(['id', 'created_at', 'fullmessage', 'location', 'place', 'retweetcount',
#        'tweet', 'user_id'],
#       dtype='object')

# %%
query = "INSERT INTO tweets_count(user_id, location, tweet, retweet_count,created_at) VALUES (?,?,?,?,?)"
prepared = cursor_twitter.prepare(query)

# %%
for index, data in tweets_count.iterrows():
    cursor_twitter.execute(prepared, (data.user_id,data.location,data.tweet,data.retweetcount,data.created_at))

# %% [markdown]
# ### Reading data for all users where they have more than 20 tweets to a dataframe.
# ### Creating a new table with this dataframe and write this data into a table.

# %%
query = "select * from tweets_count"
users_with_tweets_more_than_20 = pd.DataFrame(list(cursor_twitter.execute(query)))

users_with_tweets_more_than_20.head(10)
# Out:
#               user_id                      created_at     location  \
# 0  778395329599111169  Fri Apr 03 17:16:36 +0000 2020  Oregon, USA
# 1  778395329599111169  Fri Apr 03 17:17:59 +0000 2020  Oregon, USA
# 2  778395329599111169  Fri Apr 03 17:22:40 +0000 2020  Oregon, USA
# 3  778395329599111169  Fri Apr 03 17:23:41 +0000 2020  Oregon, USA
# 4  778395329599111169  Fri Apr 03 17:25:45 +0000 2020  Oregon, USA
# 5  778395329599111169  Fri Apr 03 17:26:44 +0000 2020  Oregon, USA
# 6  778395329599111169  Fri Apr 03 17:28:08 +0000 2020  Oregon, USA
# 7  778395329599111169  Fri Apr 03 17:29:36 +0000 2020  Oregon, USA
# 8  778395329599111169  Fri Apr 03 17:29:49 +0000 2020  Oregon, USA
# 9  778395329599111169  Fri Apr 03 17:31:10 +0000 2020  Oregon, USA
#
#    retweet_count                                              tweet
# 0              0  RT @DerekCressman: People who’d dealt with Kus...
# 1              0  RT @girlsreallyrule: Here is Captain Crozier w...
# 2              0  RT @KamalaHarris: Fifty days ago I attended a ...
# 3              0  RT @glennkirschner2: Trump’s responsibility fo...
# 4              0  RT @jaketapper: Hey does anyone know anyone wh...
# 5              0  RT @SethAbramson: The only people not profound...
# 6              0  RT @brianstelter: This is a stunning lie, and ...
# 7              0  RT @neeratanden: Over 6,000 Americans have die...
# 8              0  RT @ddale8: Once more: The president pushed ba...
# 9              0  RT @gtconway3d: “Kushner has succeeded at exac...

# %% [markdown]
# #### There are many attributes in a tweet which are not added, you can experiment with adding geolocation and many more interesting attributes to analyze data.
#
# ### Happy Coding
